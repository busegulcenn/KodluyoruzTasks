# %% [markdown]
# ### Ödev 1
#
# liste = ["Python",True,9,"3",8.4,"Hi-Kod","False",4.7]
#
# 1. Aşağıdaki işlemleri indexing ve slicing kullanarak liste üzerinde uygulayın.
#
#    - "3" değerine ulaşmak için indexleme yapın.
#    - "Hi-Kod" değerine ulaşmak için indexleme yapın.
#    - 4.7 değerine ulaşmak için indexleme yapın.
#    - 9,"3",8.4,"Hi-Kod" değerlerine ulaşmak için slicing yapın.
#    - 8.4,"Hi-Kod","False",4.7 değerlerine ulaşmak için slicing yapın.

# %%
liste = ["Python",True,9,"3",8.4,"Hi-Kod","False",4.7]
print(liste[3])
print(liste[5])
print(liste[-1])
print(liste[2:6])
print(liste[4:])
# Out:
# 3
# Hi-Kod
# 4.7
# [9, '3', 8.4, 'Hi-Kod']
# [8.4, 'Hi-Kod', 'False', 4.7]

# %% [markdown]
# ### Ödev 2
#
# Verilen listede bulunan string veri tipindeki öğeleri yeni_liste isimli listeye eklenir.
#
# liste = ["Python",True,9,"3",8.4,"Hi-Kod","False",4.7]

# %%
liste = ["Python",True,9,"3",8.4,"Hi-Kod","False",4.7]
yeni_liste = []

for i in liste:
    if type(i) == str:
        yeni_liste.append(i)

print(yeni_liste)
# Out:
# ['Python', '3', 'Hi-Kod', 'False']

# %% [markdown]
# ### Ödev 3
#
# Enumerate methodunu araştırın ve aşağıdaki örneği enumerate methodu ile yapın.

# %%
meyveler = ["elma","armut","muz","çilek","ayva","kiraz"]

for index in range(len(meyveler)):

    print("{}. indexte bulunan meyve: {}".format(index,meyveler[index]))
# Out:
# 0. indexte bulunan meyve: elma
# 1. indexte bulunan meyve: armut
# 2. indexte bulunan meyve: muz
# 3. indexte bulunan meyve: çilek
# 4. indexte bulunan meyve: ayva
# 5. indexte bulunan meyve: kiraz

# %%
for index, meyve in enumerate(meyveler):
    print(f"{index}. indexte bulunan meyve: {meyve}")
# Out:
# 0. indexte bulunan meyve: elma
# 1. indexte bulunan meyve: armut
# 2. indexte bulunan meyve: muz
# 3. indexte bulunan meyve: çilek
# 4. indexte bulunan meyve: ayva
# 5. indexte bulunan meyve: kiraz

# %% [markdown]
# ## Sozluk

# %% [markdown]
# 1. Bir sözlük oluşturulur ve bu sözlükte öğrencilerin isimleri ve Matematik, Fizik, Kimya notları tutulur. Kullanıcıdan isim ve ders ismi(Matematik, Fizik, Kimya) istenir ve bu bilgilere göre çıktı verilir.

# %%
notlar = {
    "Buse": {"Matematik": 90, "Fizik": 85, "Kimya": 88},
    "Ali": {"Matematik": 75, "Fizik": 80, "Kimya": 70},
    "Zeynep": {"Matematik": 95, "Fizik": 92, "Kimya": 89}
}

# %%
isim = input("Öğrenci adını girin: ")
ders = input("Ders adını girin: ")

if isim in notlar:
    if ders in notlar[isim]:
        print(f"{isim} isimli öğrencinin {ders} notu: {notlar[isim][ders]}")
    else:
        print("Ders bulunamadı!")
else:
    print("Öğrenci bulunamadı!")
# Out:
# Öğrenci adını girin:  Selim
# Ders adını girin:  Matematik
# Öğrenci bulunamadı!

# %%
isim = input("Öğrenci adını girin: ")
ders = input("Ders adını girin: ")

if isim in notlar:
    if ders in notlar[isim]:
        print(f"{isim} isimli öğrencinin {ders} notu: {notlar[isim][ders]}")
    else:
        print("Ders bulunamadı!")
else:
    print("Öğrenci bulunamadı!")
# Out:
# Öğrenci adını girin:  Buse
# Ders adını girin:  Kimya
# Buse isimli öğrencinin Kimya notu: 88

# %% [markdown]
# 2. Sözlük üzerinde değerleri değiştirme, yeni değer ekleme, kullanıcıya ulaşmak istediği bilgileri sorma gibi uygulamalar yapın.

# %%
notlar["Selim"] = {"Matematik" : 100, "Fizik" : 98, "Kimya" : 95} #yeni değer ekleme

# %%
notlar
# Out:
# {'Buse': {'Matematik': 90, 'Fizik': 85, 'Kimya': 88},
#  'Ali': {'Matematik': 75, 'Fizik': 80, 'Kimya': 70},
#  'Zeynep': {'Matematik': 95, 'Fizik': 92, 'Kimya': 89},
#  'Selim': {'Matematik': 100, 'Fizik': 98, 'Kimya': 95}}

# %%
notlar["Ali"]["Fizik"] = 85

# %%
notlar["Ali"]["Fizik"]
# Out:
# 85

# %%
print("\nGüncel öğrenci notları:")
for ogrenci, dersler in notlar.items():
    print(f"{ogrenci}:")
    for ders_adi, notu in dersler.items():
        print(f"  {ders_adi}: {notu}")
# Out:
# Güncel öğrenci notları:
# Buse:
#   Matematik: 90
#   Fizik: 85
#   Kimya: 88
# Ali:
#   Matematik: 75
#   Fizik: 80
#   Kimya: 70
# Zeynep:
#   Matematik: 95
#   Fizik: 92
#   Kimya: 89
# Selim:
#   Matematik: 100
#   Fizik: 98
#   Kimya: 95
